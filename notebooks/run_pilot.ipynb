# %% [markdown]
# # Run the frozen pilot
# Run the timing gate first, then use its recommended profile without inspecting test results.

# %%
# !quanova-qml smoke --config configs/smoke.yaml
# Choose exactly one profile from results/summaries/timing_gate.json
# !quanova-qml run --config configs/pilot_min.yaml --resume
# !quanova-qml shots --config configs/shots.yaml
# !quanova-qml summarize
# !quanova-qml verify
