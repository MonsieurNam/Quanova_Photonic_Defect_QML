# %% [markdown]
# # Quanova photonic defect QML — Colab runner
# Colab is an execution target. Every algorithm and protocol setting comes from the repository CLI/configs.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
PROJECT = '/content/drive/MyDrive/Quanova_Photonic_Defect_QML'
# %cd {PROJECT}
# !python -m pip install -e '.[clip,photonic]'

# %%
import os
os.environ['TORCH_HOME'] = f'{PROJECT}/cache/torch'
os.environ['HF_HOME'] = f'{PROJECT}/cache/huggingface'
os.environ['TMPDIR'] = f'{PROJECT}/cache/tmp'
# !quanova-qml embed --config configs/base.yaml
